# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# # W4D4 - Sum of Pairs (Optional)<br>
# <br>
# https://www.codewars.com/kata/54d81488b981293527000c8f/train/python<br>
# complete the above code wars problem with an optimized solution that satisfies the time out constraint.

# %%
from bigO import BigO
from bigO import algorithm
from random import randint

# %%
import numpy as np

# %%
def sum_pairs(ints, s):
    """
    Given a list of integers (int) and a single sum value (s), 
    return the first two values (parse from the left please) 
    in order of appearance that add up to form the sum.
    
    Time and space complexity (O(n)) for both.
    1. Iterate through the list of integers.
    2. Calculate the complement between that integer and the sum.
    3. Check if we have that combination of complement and integer.
    4. Add to that set of seen integers. 
    """
    seen = set() # Keep track of which numbers we've seen. 
    
    for num in ints: # Iterate through the list of integers
        complement = s - num # Find the complement of what we need to 
                             # add to get the sum. 
        if complement in seen: # If the complement is in the set of what we've seen,
            return [complement, num] # Return that complement and the number. 
        
        seen.add(num) # Add it to the list of seen integers.
    
    return None

# %%
def sum_pairsv2(ints):
    """
    Given a list of integers (int) and a single sum value (s), 
    return the first two values (parse from the left please) 
    in order of appearance that add up to form the sum.
    
    Time and space complexity (O(n)) for both.
    1. Iterate through the list of integers.
    2. Calculate the complement between that integer and the sum.
    3. Check if we have that combination of complement and integer.
    4. Add to that set of seen integers. 
    """
    seen = set() # Keep track of which numbers we've seen. 
    
    for num in ints: # Iterate through the list of integers
        complement = 500 - num # Find the complement of what we need to 
                             # add to get the sum. 
        if complement in seen: # If the complement is in the set of what we've seen,
            return [complement, num] # Return that complement and the number. 
        
        seen.add(num) # Add it to the list of seen integers.
    
    return None

# %% [markdown]
# Test out the complexity with some list of numbers from Codewars.

# %%
inputlist = [1, 4, 8, 7, 3, 15, 20, 21, 40, 48, 89]

# %%
lib = BigO()
complexity = lib.runtime(sum_pairsv2, inputlist)
# Took 0.00000s to sort sum_pairsv2(inputlist)

# %% [markdown]
# Test it out with a list of random integers

# %%
customlist = list(np.random.randint(200, size=1000))
complexity = lib.runtime(sum_pairsv2, customlist)
# Took 0.00023s to sort sum_pairsv2(custom)

# %%
complexity = lib.test(sum_pairsv2, "random")
# Completed sum_pairsv2(random array): O(n)
